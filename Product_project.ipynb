# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import numpy as np

# %%
df=pd.read_csv(r"C:\Users\user\Desktop\product project\quality_data_250k_final_nightmare.csv")

# %%
df.head()
# Out:
#   machine_id         product_type    batch_id  temperature  vibration  \
# 0         M2       Aluminum_Plate  BATCH_9541    60.516882  15.570654
# 1         M1    Plastic_Component  BATCH_7778    73.716533  18.163615
# 2         M2  High_Strength_Steel  BATCH_7076    72.024109  29.363182
# 3         M3       Aluminum_Plate  BATCH_7400    66.565796  29.103522
# 4         M2  High_Strength_Steel  BATCH_2557    56.797057  13.990520
#
#      pressure  tool_wear  machine_speed  cooling_rate  cycle_time  \
# 0  193.968593  21.200819    1055.590951     14.784410   16.219880
# 1  161.659122  38.681542    1286.481106      9.926540   15.426493
# 2  227.149763  44.354192    1203.444629      9.697653   15.308442
# 3  232.123124  13.616207    1004.650315     12.123737   12.396659
# 4  199.335505  37.123928    1168.910887      6.501700    8.465225
#
#   product_sensitivity material_quality operator_skill_level  stress_index  \
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 255000 entries, 0 to 254999
# Data columns (total 18 columns):
#  #   Column                Non-Null Count   Dtype
# ---  ------                --------------   -----
#  0   machine_id            255000 non-null  object
#  1   product_type          255000 non-null  object
#  2   batch_id              255000 non-null  object
#  3   temperature           249933 non-null  float64
#  4   vibration             249929 non-null  float64
#  5   pressure              249892 non-null  float64
#  6   tool_wear             249786 non-null  float64
#  7   machine_speed         255000 non-null  float64
#  8   cooling_rate          255000 non-null  float64
#  9   cycle_time            255000 non-null  float64
#  10  product_sensitivity   255000 non-null  object
#  11  material_quality      255000 non-null  object
#  12  operator_skill_level  255000 non-null  object
#  13  stress_index          255000 non-null  float64
# ...

# %%
df.duplicated().sum()
# Out:
# np.int64(5000)

# %%
df.drop_duplicates(inplace=True)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 250000 entries, 0 to 249999
# Data columns (total 18 columns):
#  #   Column                Non-Null Count   Dtype
# ---  ------                --------------   -----
#  0   machine_id            250000 non-null  object
#  1   product_type          250000 non-null  object
#  2   batch_id              250000 non-null  object
#  3   temperature           245048 non-null  float64
#  4   vibration             245036 non-null  float64
#  5   pressure              244986 non-null  float64
#  6   tool_wear             244876 non-null  float64
#  7   machine_speed         250000 non-null  float64
#  8   cooling_rate          250000 non-null  float64
#  9   cycle_time            250000 non-null  float64
#  10  product_sensitivity   250000 non-null  object
#  11  material_quality      250000 non-null  object
#  12  operator_skill_level  250000 non-null  object
#  13  stress_index          250000 non-null  float64
# ...

# %%
df.duplicated().sum()
# Out:
# np.int64(0)

# %%
df['product_type'].value_counts()
# Out:
# product_type
# High_Strength_Steel    80503
# Aluminum_Plate         80266
# Plastic_Component      79319
# PLASTIC_COMPONENT       1687
# high_strength_steel     1684
# plastic_component       1682
# ALUMINUM_PLATE          1679
# HIGH_STRENGTH_STEEL     1649
# aluminum_plate          1531
# Name: count, dtype: int64

# %%
product_mapp={
    "High_Strength_Steel":"High Strength Steel",
    "Aluminum_Plate":"Aluminium Plate",
    "Plastic_Component":"Plastic Component",
    "PLASTIC_COMPONENT":"Plastic Component",
    "high_strength_steel":"High Strength Steel",
    "plastic_component":"Plastic Component",
    "ALUMINUM_PLATE":"Aluminium Plate",
    "HIGH_STRENGTH_STEEL":"High Strength Steel",
    "aluminum_plate":"Aluminium Plate"
}

# %%
df['product_type'].replace(product_mapp)
# Out:
# 0             Aluminium Plate
# 1           Plastic Component
# 2         High Strength Steel
# 3             Aluminium Plate
# 4         High Strength Steel
#                  ...
# 249995    High Strength Steel
# 249996      Plastic Component
# 249997      Plastic Component
# 249998      Plastic Component
# 249999      Plastic Component
# Name: product_type, Length: 250000, dtype: object

# %%
df['product_type']=df['product_type'].replace(product_mapp)

# %%
df['product_type'].value_counts()
# Out:
# product_type
# High Strength Steel    83836
# Aluminium Plate        83476
# Plastic Component      82688
# Name: count, dtype: int64

# %%
df['product_type'].str.strip()
# Out:
# 0             Aluminium Plate
# 1           Plastic Component
# 2         High Strength Steel
# 3             Aluminium Plate
# 4         High Strength Steel
#                  ...
# 249995    High Strength Steel
# 249996      Plastic Component
# 249997      Plastic Component
# 249998      Plastic Component
# 249999      Plastic Component
# Name: product_type, Length: 250000, dtype: object

# %%
df['product_type']=df['product_type'].str.strip()

# %%
df['batch_id'].value_counts()
# Out:
# batch_id
# BATCH_2316    51
# BATCH_5864    51
# BATCH_4988    50
# BATCH_5757    49
# BATCH_3472    47
#               ..
# BATCH_7685    12
# BATCH_7839    12
# BATCH_2382    12
# BATCH_6963    11
# BATCH_3084    11
# Name: count, Length: 9000, dtype: int64

# %%
df['product_type'].isnull().sum()
# Out:
# np.int64(0)

# %%
df['temperature'].isnull().sum()
# Out:
# np.int64(4952)

# %%
df.dropna(subset='temperature',inplace=True)

# %%
df['temperature'].isnull().sum()
# Out:
# np.int64(0)

# %%
df['temperature'].unique()[0:1000]
# Out:
# array([  60.51688164,   73.71653267,   72.02410867,   66.56579597,
#          56.79705682,   65.0113156 ,   62.4101233 ,   62.57593635,
#          51.1461462 ,   71.48455651,   61.64643687,   69.43336647,
#          90.54462561,   67.90889107,   70.52690585,   71.19267983,
#          67.39229113,   73.97576261,   50.72520657,   64.55349566,
#          68.22672741,   61.86624856,   59.35907896,   67.92      ,
#          54.71710186,   99.86347284,   94.94775825,   69.20116693,
#          63.06901266,   73.65577636,   57.85533333,   68.8631359 ,
#          54.50874838,   60.89373973,   73.11319328,   55.16856038,
#          72.40852478,   82.44397871,   66.75317849,   66.5998999 ,
#          61.27278907,   57.81827642,   76.10538807,   56.46239837,
#          90.27709958,   94.57473015,   55.16467448,   71.29337153,
#          69.07949816,   73.42623311,   58.57816069,   86.32344059,
#          64.45164714,   71.6134254 ,   58.45739955,   54.53856528,
# ...

# %%
df['temperature']=df['temperature'].round(2)

# %%
df.head()
# Out:
#   machine_id         product_type    batch_id  temperature  vibration  \
# 0         M2      Aluminium Plate  BATCH_9541        60.52  15.570654
# 1         M1    Plastic Component  BATCH_7778        73.72  18.163615
# 2         M2  High Strength Steel  BATCH_7076        72.02  29.363182
# 3         M3      Aluminium Plate  BATCH_7400        66.57  29.103522
# 4         M2  High Strength Steel  BATCH_2557        56.80  13.990520
#
#      pressure  tool_wear  machine_speed  cooling_rate  cycle_time  \
# 0  193.968593  21.200819    1055.590951     14.784410   16.219880
# 1  161.659122  38.681542    1286.481106      9.926540   15.426493
# 2  227.149763  44.354192    1203.444629      9.697653   15.308442
# 3  232.123124  13.616207    1004.650315     12.123737   12.396659
# 4  199.335505  37.123928    1168.910887      6.501700    8.465225
#
#   product_sensitivity material_quality operator_skill_level  stress_index  \
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 245048 entries, 0 to 249999
# Data columns (total 18 columns):
#  #   Column                Non-Null Count   Dtype
# ---  ------                --------------   -----
#  0   machine_id            245048 non-null  object
#  1   product_type          245048 non-null  object
#  2   batch_id              245048 non-null  object
#  3   temperature           245048 non-null  float64
#  4   vibration             240178 non-null  float64
#  5   pressure              240144 non-null  float64
#  6   tool_wear             240052 non-null  float64
#  7   machine_speed         245048 non-null  float64
#  8   cooling_rate          245048 non-null  float64
#  9   cycle_time            245048 non-null  float64
#  10  product_sensitivity   245048 non-null  object
#  11  material_quality      245048 non-null  object
#  12  operator_skill_level  245048 non-null  object
#  13  stress_index          245048 non-null  float64
# ...

# %%
df['vibration'].isnull().any()
# Out:
# np.True_

# %%
df['vibration'].isnull().sum()
# Out:
# np.int64(4870)

# %%
df.dropna(subset='vibration',inplace=True)

# %%
df['vibration'].isnull().sum()
# Out:
# np.int64(0)

# %%
df['vibration']=df['vibration'].round(2)

# %%
df.head()
# Out:
#   machine_id         product_type    batch_id  temperature  vibration  \
# 0         M2      Aluminium Plate  BATCH_9541        60.52      15.57
# 1         M1    Plastic Component  BATCH_7778        73.72      18.16
# 2         M2  High Strength Steel  BATCH_7076        72.02      29.36
# 3         M3      Aluminium Plate  BATCH_7400        66.57      29.10
# 4         M2  High Strength Steel  BATCH_2557        56.80      13.99
#
#      pressure  tool_wear  machine_speed  cooling_rate  cycle_time  \
# 0  193.968593  21.200819    1055.590951     14.784410   16.219880
# 1  161.659122  38.681542    1286.481106      9.926540   15.426493
# 2  227.149763  44.354192    1203.444629      9.697653   15.308442
# 3  232.123124  13.616207    1004.650315     12.123737   12.396659
# 4  199.335505  37.123928    1168.910887      6.501700    8.465225
#
#   product_sensitivity material_quality operator_skill_level  stress_index  \
# ...

# %%
df['pressure'].isnull().sum()
# Out:
# np.int64(4816)

# %%
df.dropna(subset='pressure',inplace=True)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 235362 entries, 0 to 249999
# Data columns (total 18 columns):
#  #   Column                Non-Null Count   Dtype
# ---  ------                --------------   -----
#  0   machine_id            235362 non-null  object
#  1   product_type          235362 non-null  object
#  2   batch_id              235362 non-null  object
#  3   temperature           235362 non-null  float64
#  4   vibration             235362 non-null  float64
#  5   pressure              235362 non-null  float64
#  6   tool_wear             230568 non-null  float64
#  7   machine_speed         235362 non-null  float64
#  8   cooling_rate          235362 non-null  float64
#  9   cycle_time            235362 non-null  float64
#  10  product_sensitivity   235362 non-null  object
#  11  material_quality      235362 non-null  object
#  12  operator_skill_level  235362 non-null  object
#  13  stress_index          235362 non-null  float64
# ...

# %%
df['pressure'].head()
# Out:
# 0    193.968593
# 1    161.659122
# 2    227.149763
# 3    232.123124
# 4    199.335505
# Name: pressure, dtype: float64

# %%
df['pressure']=df['pressure'].round(2)

# %%
df['pressure'].isnull().sum()
# Out:
# np.int64(0)

# %%
df.head()
# Out:
#   machine_id         product_type    batch_id  temperature  vibration  \
# 0         M2      Aluminium Plate  BATCH_9541        60.52      15.57
# 1         M1    Plastic Component  BATCH_7778        73.72      18.16
# 2         M2  High Strength Steel  BATCH_7076        72.02      29.36
# 3         M3      Aluminium Plate  BATCH_7400        66.57      29.10
# 4         M2  High Strength Steel  BATCH_2557        56.80      13.99
#
#    pressure  tool_wear  machine_speed  cooling_rate  cycle_time  \
# 0    193.97  21.200819    1055.590951     14.784410   16.219880
# 1    161.66  38.681542    1286.481106      9.926540   15.426493
# 2    227.15  44.354192    1203.444629      9.697653   15.308442
# 3    232.12  13.616207    1004.650315     12.123737   12.396659
# 4    199.34  37.123928    1168.910887      6.501700    8.465225
#
#   product_sensitivity material_quality operator_skill_level  stress_index  \
# 0                High           Medium               Expert      9.422875
# ...

# %%
df['tool_wear'].info()
# Out:
# <class 'pandas.core.series.Series'>
# Index: 235362 entries, 0 to 249999
# Series name: tool_wear
# Non-Null Count   Dtype
# --------------   -----
# 230568 non-null  float64
# dtypes: float64(1)
# memory usage: 3.6 MB

# %%
df['tool_wear'].isnull().sum()
# Out:
# np.int64(4794)

# %%
df.dropna(subset='tool_wear',inplace=True)

# %%
df['tool_wear'].isnull().sum()
# Out:
# np.int64(0)

# %%
df['tool_wear']=df['tool_wear'].round(2)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 230568 entries, 0 to 249999
# Data columns (total 18 columns):
#  #   Column                Non-Null Count   Dtype
# ---  ------                --------------   -----
#  0   machine_id            230568 non-null  object
#  1   product_type          230568 non-null  object
#  2   batch_id              230568 non-null  object
#  3   temperature           230568 non-null  float64
#  4   vibration             230568 non-null  float64
#  5   pressure              230568 non-null  float64
#  6   tool_wear             230568 non-null  float64
#  7   machine_speed         230568 non-null  float64
#  8   cooling_rate          230568 non-null  float64
#  9   cycle_time            230568 non-null  float64
#  10  product_sensitivity   230568 non-null  object
#  11  material_quality      230568 non-null  object
#  12  operator_skill_level  230568 non-null  object
#  13  stress_index          230568 non-null  float64
# ...

# %%
df['machine_speed'].isnull().sum()
# Out:
# np.int64(0)

# %%
df['machine_speed'].head()
# Out:
# 0    1055.590951
# 1    1286.481106
# 2    1203.444629
# 3    1004.650315
# 4    1168.910887
# Name: machine_speed, dtype: float64

# %%
df['machine_speed']=df['machine_speed'].round(2)

# %%
df['machine_speed'].head()
# Out:
# 0    1055.59
# 1    1286.48
# 2    1203.44
# 3    1004.65
# 4    1168.91
# Name: machine_speed, dtype: float64

# %%
df.head()
# Out:
#   machine_id         product_type    batch_id  temperature  vibration  \
# 0         M2      Aluminium Plate  BATCH_9541        60.52      15.57
# 1         M1    Plastic Component  BATCH_7778        73.72      18.16
# 2         M2  High Strength Steel  BATCH_7076        72.02      29.36
# 3         M3      Aluminium Plate  BATCH_7400        66.57      29.10
# 4         M2  High Strength Steel  BATCH_2557        56.80      13.99
#
#    pressure  tool_wear  machine_speed  cooling_rate  cycle_time  \
# 0    193.97      21.20        1055.59     14.784410   16.219880
# 1    161.66      38.68        1286.48      9.926540   15.426493
# 2    227.15      44.35        1203.44      9.697653   15.308442
# 3    232.12      13.62        1004.65     12.123737   12.396659
# 4    199.34      37.12        1168.91      6.501700    8.465225
#
#   product_sensitivity material_quality operator_skill_level  stress_index  \
# 0                High           Medium               Expert      9.422875
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 230568 entries, 0 to 249999
# Data columns (total 18 columns):
#  #   Column                Non-Null Count   Dtype
# ---  ------                --------------   -----
#  0   machine_id            230568 non-null  object
#  1   product_type          230568 non-null  object
#  2   batch_id              230568 non-null  object
#  3   temperature           230568 non-null  float64
#  4   vibration             230568 non-null  float64
#  5   pressure              230568 non-null  float64
#  6   tool_wear             230568 non-null  float64
#  7   machine_speed         230568 non-null  float64
#  8   cooling_rate          230568 non-null  float64
#  9   cycle_time            230568 non-null  float64
#  10  product_sensitivity   230568 non-null  object
#  11  material_quality      230568 non-null  object
#  12  operator_skill_level  230568 non-null  object
#  13  stress_index          230568 non-null  float64
# ...

# %%
df['cooling_rate'].isnull().sum()
# Out:
# np.int64(0)

# %%
df['cooling_rate']=df['cooling_rate'].round(2)

# %%
df['cycle_time'].isnull().sum()
# Out:
# np.int64(0)

# %%
df['cycle_time']=df['cycle_time'].round(2)

# %%
df['product_sensitivity'].head()
# Out:
# 0      High
# 1      High
# 2    Medium
# 3      High
# 4       Low
# Name: product_sensitivity, dtype: object

# %%
df['product_sensitivity'].unique()
# Out:
# array(['High', 'Medium', 'Low'], dtype=object)

# %%
df['product_sensitivity'].value_counts()
# Out:
# product_sensitivity
# Low       77087
# Medium    76880
# High      76601
# Name: count, dtype: int64

# %%
df['product_sensitivity']=df['product_sensitivity'].str.strip()

# %%
df['material_quality'].head()
# Out:
# 0    Medium
# 1    Medium
# 2      High
# 3       Low
# 4      High
# Name: material_quality, dtype: object

# %%
df['material_quality'].value_counts()
# Out:
# material_quality
# Low        82280
# Medium     73159
# High       72731
# unknown     2398
# Name: count, dtype: int64

# %%
df['material_quality'].str.capitalize()
# Out:
# 0         Medium
# 1         Medium
# 2           High
# 3            Low
# 4           High
#            ...
# 249995    Medium
# 249996       Low
# 249997    Medium
# 249998      High
# 249999      High
# Name: material_quality, Length: 230568, dtype: object

# %%
df['material_quality']=df['material_quality'].str.capitalize()

# %%
df['material_quality'].value_counts()
# Out:
# material_quality
# Low        82280
# Medium     73159
# High       72731
# Unknown     2398
# Name: count, dtype: int64

# %%
df['material_quality'].isnull().sum()
# Out:
# np.int64(0)

# %%
df['material_quality']=df['material_quality'].str.strip()

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 230568 entries, 0 to 249999
# Data columns (total 18 columns):
#  #   Column                Non-Null Count   Dtype
# ---  ------                --------------   -----
#  0   machine_id            230568 non-null  object
#  1   product_type          230568 non-null  object
#  2   batch_id              230568 non-null  object
#  3   temperature           230568 non-null  float64
#  4   vibration             230568 non-null  float64
#  5   pressure              230568 non-null  float64
#  6   tool_wear             230568 non-null  float64
#  7   machine_speed         230568 non-null  float64
#  8   cooling_rate          230568 non-null  float64
#  9   cycle_time            230568 non-null  float64
#  10  product_sensitivity   230568 non-null  object
#  11  material_quality      230568 non-null  object
#  12  operator_skill_level  230568 non-null  object
#  13  stress_index          230568 non-null  float64
# ...

# %%
df['operator_skill_level'].isnull().sum()
# Out:
# np.int64(0)

# %%
df['operator_skill_level'].value_counts()
# Out:
# operator_skill_level
# Expert          74049
# Intermediate    73678
# Junior          73581
# junior           1579
# INTERMEDIATE     1563
# expert           1563
# intermediate     1545
# EXPERT           1524
# JUNIOR           1486
# Name: count, dtype: int64

# %%
skill_mapp={
    "EXPERT":"Expert",
    "JUNIOR":"Junior",
    "INTERMEDIATE":"Intermediate",
    "junior":"Junior",
    "expert":"Expert",
    "intermediate":"Intermediate"
}

# %%
df['operator_skill_level'].replace(skill_mapp)
# Out:
# 0               Expert
# 1               Junior
# 2         Intermediate
# 3         Intermediate
# 4         Intermediate
#               ...
# 249995          Expert
# 249996          Junior
# 249997    Intermediate
# 249998          Expert
# 249999          Junior
# Name: operator_skill_level, Length: 230568, dtype: object

# %%
df['operator_skill_level']=df['operator_skill_level'].replace(skill_mapp)

# %%
df['operator_skill_level'].value_counts()
# Out:
# operator_skill_level
# Expert          77136
# Intermediate    76786
# Junior          76646
# Name: count, dtype: int64

# %%
df['operator_skill_level']=df['operator_skill_level'].str.strip()

# %%
df.head()
# Out:
#   machine_id         product_type    batch_id  temperature  vibration  \
# 0         M2      Aluminium Plate  BATCH_9541        60.52      15.57
# 1         M1    Plastic Component  BATCH_7778        73.72      18.16
# 2         M2  High Strength Steel  BATCH_7076        72.02      29.36
# 3         M3      Aluminium Plate  BATCH_7400        66.57      29.10
# 4         M2  High Strength Steel  BATCH_2557        56.80      13.99
#
#    pressure  tool_wear  machine_speed  cooling_rate  cycle_time  \
# 0    193.97      21.20        1055.59         14.78       16.22
# 1    161.66      38.68        1286.48          9.93       15.43
# 2    227.15      44.35        1203.44          9.70       15.31
# 3    232.12      13.62        1004.65         12.12       12.40
# 4    199.34      37.12        1168.91          6.50        8.47
#
#   product_sensitivity material_quality operator_skill_level  stress_index  \
# 0                High           Medium               Expert      9.422875
# ...

# %%
df['stress_index'].isnull().sum()
# Out:
# np.int64(0)

# %%
df['stress_index']=df['stress_index'].round(2)

# %%
df['quality_score'].isnull().sum()
# Out:
# np.int64(0)

# %%
df['quality_score']=df['quality_score'].round(2)

# %%
df['defect_type'].isnull().sum()
# Out:
# np.int64(0)

# %%
df['defect_type'].unique()
# Out:
# array(['No_Defect', 'Porosity', 'Warping', 'Misalignment', 'Deformation',
#        'Surface_Defect'], dtype=object)

# %%
df['defect_type'].str.replace('No_Defect','No defect')
# Out:
# 0         No defect
# 1         No defect
# 2         No defect
# 3         No defect
# 4         No defect
#             ...
# 249995    No defect
# 249996    No defect
# 249997    No defect
# 249998    No defect
# 249999    No defect
# Name: defect_type, Length: 230568, dtype: object

# %%
df['defect_type']=df['defect_type'].str.replace('No_Defect','No defect')

# %%
df['defect_type'].unique()
# Out:
# array(['No defect', 'Porosity', 'Warping', 'Misalignment', 'Deformation',
#        'Surface_Defect'], dtype=object)

# %%
df['defect_type'].value_counts()
# Out:
# defect_type
# No defect         184252
# Deformation         9416
# Surface_Defect      9323
# Porosity            9244
# Misalignment        9192
# Warping             9141
# Name: count, dtype: int64

# %%
df['defect_type']=df['defect_type'].str.strip()

# %%
df.head()
# Out:
#   machine_id         product_type    batch_id  temperature  vibration  \
# 0         M2      Aluminium Plate  BATCH_9541        60.52      15.57
# 1         M1    Plastic Component  BATCH_7778        73.72      18.16
# 2         M2  High Strength Steel  BATCH_7076        72.02      29.36
# 3         M3      Aluminium Plate  BATCH_7400        66.57      29.10
# 4         M2  High Strength Steel  BATCH_2557        56.80      13.99
#
#    pressure  tool_wear  machine_speed  cooling_rate  cycle_time  \
# 0    193.97      21.20        1055.59         14.78       16.22
# 1    161.66      38.68        1286.48          9.93       15.43
# 2    227.15      44.35        1203.44          9.70       15.31
# 3    232.12      13.62        1004.65         12.12       12.40
# 4    199.34      37.12        1168.91          6.50        8.47
#
#   product_sensitivity material_quality operator_skill_level  stress_index  \
# 0                High           Medium               Expert          9.42
# ...

# %%
df['quality_level']=df['quality_level'].str.strip()

# %%
df['quality_level'].isnull().sum()
# Out:
# np.int64(0)

# %%
df['quality_level'].unique()
# Out:
# array(['Medium', 'High', 'Low'], dtype=object)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 230568 entries, 0 to 249999
# Data columns (total 18 columns):
#  #   Column                Non-Null Count   Dtype
# ---  ------                --------------   -----
#  0   machine_id            230568 non-null  object
#  1   product_type          230568 non-null  object
#  2   batch_id              230568 non-null  object
#  3   temperature           230568 non-null  float64
#  4   vibration             230568 non-null  float64
#  5   pressure              230568 non-null  float64
#  6   tool_wear             230568 non-null  float64
#  7   machine_speed         230568 non-null  float64
#  8   cooling_rate          230568 non-null  float64
#  9   cycle_time            230568 non-null  float64
#  10  product_sensitivity   230568 non-null  object
#  11  material_quality      230568 non-null  object
#  12  operator_skill_level  230568 non-null  object
#  13  stress_index          230568 non-null  float64
# ...

# %%
df.describe()
# Out:
#          temperature      vibration       pressure      tool_wear  \
# count  230568.000000  230568.000000  230568.000000  230568.000000
# mean       64.934424      21.243970     197.720187      32.023476
# std        40.240650      16.368736     119.461622      26.067968
# min      -328.680000    -200.250000    -748.830000    -290.140000
# 25%        56.790000      14.960000     173.980000      20.030000
# 50%        64.190000      20.380000     199.870000      30.850000
# 75%        71.510000      25.822500     226.080000      41.670000
# max       525.440000     329.490000    1245.140000     466.590000
#
#        machine_speed   cooling_rate     cycle_time   stress_index  \
# count  230568.000000  230568.000000  230568.000000  230568.000000
# mean     1099.950575       9.697263      13.488769      14.324656
# std       115.491516       3.190880       3.735295       7.884156
# min       900.000000       1.000000       8.000000       5.010000
# ...

# %%
df.to_csv("cleaned_data.csv",index=False)

# %% [markdown]
# ## MOVING TO EDA OF THE DATA

# %%
## looking at the correlation of our data

# %%
df.head()
# Out:
#   machine_id         product_type    batch_id  temperature  vibration  \
# 0         M2      Aluminium Plate  BATCH_9541        60.52      15.57
# 1         M1    Plastic Component  BATCH_7778        73.72      18.16
# 2         M2  High Strength Steel  BATCH_7076        72.02      29.36
# 3         M3      Aluminium Plate  BATCH_7400        66.57      29.10
# 4         M2  High Strength Steel  BATCH_2557        56.80      13.99
#
#    pressure  tool_wear  machine_speed  cooling_rate  cycle_time  \
# 0    193.97      21.20        1055.59         14.78       16.22
# 1    161.66      38.68        1286.48          9.93       15.43
# 2    227.15      44.35        1203.44          9.70       15.31
# 3    232.12      13.62        1004.65         12.12       12.40
# 4    199.34      37.12        1168.91          6.50        8.47
#
#   product_sensitivity material_quality operator_skill_level  stress_index  \
# 0                High           Medium               Expert          9.42
# ...

# %%
df_corr=df.drop(columns=['machine_id','product_type','batch_id','product_sensitivity','material_quality','operator_skill_level','defect_type','quality_level'])

# %%
df_corr.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 230568 entries, 0 to 249999
# Data columns (total 10 columns):
#  #   Column         Non-Null Count   Dtype
# ---  ------         --------------   -----
#  0   temperature    230568 non-null  float64
#  1   vibration      230568 non-null  float64
#  2   pressure       230568 non-null  float64
#  3   tool_wear      230568 non-null  float64
#  4   machine_speed  230568 non-null  float64
#  5   cooling_rate   230568 non-null  float64
#  6   cycle_time     230568 non-null  float64
#  7   stress_index   230568 non-null  float64
#  8   is_defect      230568 non-null  int64
#  9   quality_score  230568 non-null  float64
# dtypes: float64(9), int64(1)
# memory usage: 19.4 MB

# %%
plt.figure(figsize=(20,10))
sns.heatmap(df_corr.corr(),annot=True)
plt.show()

# %%
## what causes defects

# %%
average_defect=df.groupby('is_defect')[['temperature','vibration','pressure','tool_wear','machine_speed','cooling_rate','cycle_time','stress_index'
                         ,'quality_score']].mean().reset_index()

# %%
average_defect=average_defect.melt(id_vars='is_defect')

# %%
average_defect
# Out:
#     is_defect       variable        value
# 0           0    temperature    61.791756
# 1           1    temperature    77.436426
# 2           0      vibration    19.762408
# 3           1      vibration    27.137845
# 4           0       pressure   197.732246
# 5           1       pressure   197.672211
# 6           0      tool_wear    29.749109
# 7           1      tool_wear    41.071248
# 8           0  machine_speed  1099.926469
# 9           1  machine_speed  1100.046474
# 10          0   cooling_rate     9.993554
# 11          1   cooling_rate     8.518570
# 12          0     cycle_time    12.998930
# 13          1     cycle_time    15.437423
# 14          0   stress_index    12.486676
# 15          1   stress_index    21.636413
# 16          0  quality_score    75.377007
# 17          1  quality_score    30.060386

# %%
plt.figure(figsize=(20,10))
sns.barplot(data=average_defect,x='variable',y='value',hue='is_defect')
plt.title("Comparison of Defect vs No Defect Values")
# Out:
# Text(0.5, 1.0, 'Comparison of Defect vs No Defect Values')

# %%
## how does experience lead to perfomance

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 230568 entries, 0 to 249999
# Data columns (total 18 columns):
#  #   Column                Non-Null Count   Dtype
# ---  ------                --------------   -----
#  0   machine_id            230568 non-null  object
#  1   product_type          230568 non-null  object
#  2   batch_id              230568 non-null  object
#  3   temperature           230568 non-null  float64
#  4   vibration             230568 non-null  float64
#  5   pressure              230568 non-null  float64
#  6   tool_wear             230568 non-null  float64
#  7   machine_speed         230568 non-null  float64
#  8   cooling_rate          230568 non-null  float64
#  9   cycle_time            230568 non-null  float64
#  10  product_sensitivity   230568 non-null  object
#  11  material_quality      230568 non-null  object
#  12  operator_skill_level  230568 non-null  object
#  13  stress_index          230568 non-null  float64
# ...

# %%
skill_rank=df.groupby('operator_skill_level')['quality_score'].mean().reset_index()

# %%
skill_rank
# Out:
#   operator_skill_level  quality_score
# 0               Expert      69.036406
# 1         Intermediate      68.837494
# 2               Junior      60.925463

# %%
plt.figure(figsize=(12,10))
sns.barplot(data=skill_rank,x="operator_skill_level",y="quality_score")
plt.title("Skill Level Perfomance Comparison")
# Out:
# Text(0.5, 1.0, 'Skill Level Perfomance Comparison')

# %%
df.groupby('operator_skill_level')['is_defect'].mean().reset_index()
# Out:
#   operator_skill_level  is_defect
# 0               Expert   0.199336
# 1         Intermediate   0.202433
# 2               Junior   0.200872

# %%
df['machine_id'].value_counts()
# Out:
# machine_id
# M4    57986
# M2    57960
# M1    57451
# M3    57171
# Name: count, dtype: int64

# %%
df.groupby(['machine_id','operator_skill_level'])['is_defect'].mean().reset_index()
# Out:
#    machine_id operator_skill_level  is_defect
# 0          M1               Expert   0.201032
# 1          M1         Intermediate   0.199958
# 2          M1               Junior   0.202450
# 3          M2               Expert   0.196094
# 4          M2         Intermediate   0.206370
# 5          M2               Junior   0.199452
# 6          M3               Expert   0.199864
# 7          M3         Intermediate   0.200210
# 8          M3               Junior   0.201230
# 9          M4               Expert   0.200359
# 10         M4         Intermediate   0.203142
# 11         M4               Junior   0.200375

# %%
df.groupby(['machine_id','product_sensitivity'])['is_defect'].mean().reset_index()
# Out:
#    machine_id product_sensitivity  is_defect
# 0          M1                High   0.198125
# 1          M1                 Low   0.201392
# 2          M1              Medium   0.203916
# 3          M2                High   0.199242
# 4          M2                 Low   0.204768
# 5          M2              Medium   0.197948
# 6          M3                High   0.204290
# 7          M3                 Low   0.199750
# 8          M3              Medium   0.197292
# 9          M4                High   0.199586
# 10         M4                 Low   0.205454
# 11         M4              Medium   0.198793

# %%
df.groupby('material_quality')['is_defect'].mean().reset_index() ## this shows that the material qulity does in deed play a big part in mdefect
# Out:
#   material_quality  is_defect
# 0             High   0.166696
# 1              Low   0.260525
# 2           Medium   0.167608
# 3          Unknown   0.206005

# %%
quality_effects=df.groupby('material_quality')['is_defect'].mean().reset_index()

# %%
sns.barplot(quality_effects,x='material_quality',y='is_defect')
# Out:
# <Axes: xlabel='material_quality', ylabel='is_defect'>

# %%
df.groupby('material_quality')[['temperature','vibration','pressure','tool_wear','machine_speed','cooling_rate','cycle_time','stress_index'
                         ,'quality_score']].mean().reset_index()
# Out:
#   material_quality  temperature  vibration    pressure  tool_wear  \
# 0             High    65.164042  21.323455  197.312792  32.068080
# 1              Low    64.694087  21.141718  198.165865  31.865386
# 2           Medium    64.955065  21.285377  197.622314  32.132692
# 3          Unknown    65.586785  21.078399  197.770242  32.762986
#
#    machine_speed  cooling_rate  cycle_time  stress_index  quality_score
# 0    1099.974514      9.689404   13.510630     14.383849      69.943235
# 1    1100.121199      9.727603   13.439284     14.187480      65.440185
# 2    1099.703418      9.667160   13.522201     14.420515      63.583677
# 3    1100.910434      9.812969   13.503716     14.311576      65.664308

# %%
df.groupby('is_defect')['stress_index'].mean()
# Out:
# is_defect
# 0    12.486676
# 1    21.636413
# Name: stress_index, dtype: float64

# %%
df.hist(figsize=(12,10))
# Out:
# array([[<Axes: title={'center': 'temperature'}>,
#         <Axes: title={'center': 'vibration'}>,
#         <Axes: title={'center': 'pressure'}>],
#        [<Axes: title={'center': 'tool_wear'}>,
#         <Axes: title={'center': 'machine_speed'}>,
#         <Axes: title={'center': 'cooling_rate'}>],
#        [<Axes: title={'center': 'cycle_time'}>,
#         <Axes: title={'center': 'stress_index'}>,
#         <Axes: title={'center': 'is_defect'}>],
#        [<Axes: title={'center': 'quality_score'}>, <Axes: >, <Axes: >]],
#       dtype=object)

# %%
df.plot(kind='kde',subplots=True,sharex=False,layout=(4,3),figsize=(12,10))
# Out:
# array([[<Axes: ylabel='Density'>, <Axes: ylabel='Density'>,
#         <Axes: ylabel='Density'>],
#        [<Axes: ylabel='Density'>, <Axes: ylabel='Density'>,
#         <Axes: ylabel='Density'>],
#        [<Axes: ylabel='Density'>, <Axes: ylabel='Density'>,
#         <Axes: ylabel='Density'>],
#        [<Axes: ylabel='Density'>, <Axes: ylabel='Density'>,
#         <Axes: ylabel='Density'>]], dtype=object)

# %% [markdown]
# ## Modeing the first anomalee model. Model meant to detect anomalees from machine readings

# %%
from sklearn.ensemble import IsolationForest
from sklearn.compose import ColumnTransformer
from sklearn.pipeline import Pipeline
from sklearn.preprocessing import StandardScaler,MinMaxScaler
import joblib

# %%
df.describe()
# Out:
#          temperature      vibration       pressure      tool_wear  \
# count  230568.000000  230568.000000  230568.000000  230568.000000
# mean       64.934424      21.243970     197.720187      32.023476
# std        40.240650      16.368736     119.461622      26.067968
# min      -328.680000    -200.250000    -748.830000    -290.140000
# 25%        56.790000      14.960000     173.980000      20.030000
# 50%        64.190000      20.380000     199.870000      30.850000
# 75%        71.510000      25.822500     226.080000      41.670000
# max       525.440000     329.490000    1245.140000     466.590000
#
#        machine_speed   cooling_rate     cycle_time   stress_index  \
# count  230568.000000  230568.000000  230568.000000  230568.000000
# mean     1099.950575       9.697263      13.488769      14.324656
# std       115.491516       3.190880       3.735295       7.884156
# min       900.000000       1.000000       8.000000       5.010000
# ...

# %%
numericals=['temperature','vibration','pressure','tool_wear','machine_speed','cooling_rate','cycle_time','stress_index']

# %%
x_anomaly=df[numericals]

# %%
x_anomaly.head()
# Out:
#    temperature  vibration  pressure  tool_wear  machine_speed  cooling_rate  \
# 0        60.52      15.57    193.97      21.20        1055.59         14.78
# 1        73.72      18.16    161.66      38.68        1286.48          9.93
# 2        72.02      29.36    227.15      44.35        1203.44          9.70
# 3        66.57      29.10    232.12      13.62        1004.65         12.12
# 4        56.80      13.99    199.34      37.12        1168.91          6.50
#
#    cycle_time  stress_index
# 0       16.22          9.42
# 1       15.43         13.39
# 2       15.31         21.15
# 3       12.40         19.37
# 4        8.47          7.95

# %%
preprocess=ColumnTransformer([
    ('std',StandardScaler(),numericals)
])

# %%
isr=IsolationForest(
    n_estimators=200,
    contamination=0.1,
    random_state=42
)

# %%
anomalee=Pipeline([
    ('preprocess',preprocess),
    ('isr',isr)
])

# %%
anomalee.fit(x_anomaly)
# Out:
# Pipeline(steps=[('preprocess',
#                  ColumnTransformer(transformers=[('std', StandardScaler(),
#                                                   ['temperature', 'vibration',
#                                                    'pressure', 'tool_wear',
#                                                    'machine_speed',
#                                                    'cooling_rate', 'cycle_time',
#                                                    'stress_index'])])),
#                 ('isr',
#                  IsolationForest(contamination=0.1, n_estimators=200,
#                                  random_state=42))])

# %%
prediction_anomaly=anomalee.predict(x_anomaly)

# %%
prediction_anomaly
# Out:
# array([1, 1, 1, ..., 1, 1, 1])

# %%
scores=anomalee.decision_function(x_anomaly)

# %%
scores
# Out:
# array([0.08718814, 0.09100623, 0.09910316, ..., 0.10732036, 0.10406965,
#        0.04328799])

# %%
df_anomaly=df.copy()

# %%
df_anomaly.head()
# Out:
#   machine_id         product_type    batch_id  temperature  vibration  \
# 0         M2      Aluminium Plate  BATCH_9541        60.52      15.57
# 1         M1    Plastic Component  BATCH_7778        73.72      18.16
# 2         M2  High Strength Steel  BATCH_7076        72.02      29.36
# 3         M3      Aluminium Plate  BATCH_7400        66.57      29.10
# 4         M2  High Strength Steel  BATCH_2557        56.80      13.99
#
#    pressure  tool_wear  machine_speed  cooling_rate  cycle_time  \
# 0    193.97      21.20        1055.59         14.78       16.22
# 1    161.66      38.68        1286.48          9.93       15.43
# 2    227.15      44.35        1203.44          9.70       15.31
# 3    232.12      13.62        1004.65         12.12       12.40
# 4    199.34      37.12        1168.91          6.50        8.47
#
#   product_sensitivity material_quality operator_skill_level  stress_index  \
# 0                High           Medium               Expert          9.42
# ...

# %%
np.where(prediction_anomaly==-1,1,0)
# Out:
# array([0, 0, 0, ..., 0, 0, 0])

# %%
preds=np.where(prediction_anomaly==-1,1,0)

# %%
df_anomaly['anomaly']=preds

# %%
df_anomaly['anomaly'].value_counts()
# Out:
# anomaly
# 0    207511
# 1     23057
# Name: count, dtype: int64

# %%
df_anomaly['scores']=scores

# %%
df_anomaly['risk']=-df_anomaly['scores']

# %%
scaler=MinMaxScaler()

# %%
scaler.fit_transform(df_anomaly[['risk']])
# Out:
# array([[0.13129669],
#        [0.11994728],
#        [0.09587891],
#        ...,
#        [0.07145301],
#        [0.08111585],
#        [0.26179132]])

# %%
df_anomaly['risk']=scaler.fit_transform(df_anomaly[['risk']])

# %%
df_anomaly.head(50)
# Out:
#    machine_id         product_type    batch_id  temperature  vibration  \
# 0          M2      Aluminium Plate  BATCH_9541        60.52      15.57
# 1          M1    Plastic Component  BATCH_7778        73.72      18.16
# 2          M2  High Strength Steel  BATCH_7076        72.02      29.36
# 3          M3      Aluminium Plate  BATCH_7400        66.57      29.10
# 4          M2  High Strength Steel  BATCH_2557        56.80      13.99
# 5          M1    Plastic Component  BATCH_6351        65.01      13.37
# 6          M4      Aluminium Plate  BATCH_5149        62.41      19.94
# 7          M4    Plastic Component  BATCH_3496        62.58      26.05
# 8          M4  High Strength Steel  BATCH_8181        51.15      19.32
# 9          M3    Plastic Component  BATCH_8321        71.48      12.90
# 10         M3      Aluminium Plate  BATCH_5859        61.65      20.30
# 11         M2  High Strength Steel  BATCH_2172        69.43      20.85
# ...

# %%
df_anomaly.to_csv('anomalee_risk.csv',index=False)

# %%
joblib.dump(anomalee,'anomaly_model.pkl')
# Out:
# ['anomaly_model.pkl']

# %% [markdown]
# ## MOVING ON TO THE SECOND MODEL

# %%
from sklearn.model_selection import train_test_split,GridSearchCV
from sklearn.pipeline import FeatureUnion
from sklearn.ensemble import RandomForestClassifier,VotingClassifier,RandomForestRegressor
from sklearn.metrics import classification_report,confusion_matrix,r2_score,mean_absolute_error,mean_squared_error,f1_score,recall_score,precision_score
from sklearn.preprocessing import OneHotEncoder
from xgboost import XGBClassifier
from sklearn.feature_selection import SelectKBest,f_classif,f_regression

# %%
df_anomaly.head()
# Out:
#   machine_id         product_type    batch_id  temperature  vibration  \
# 0         M2      Aluminium Plate  BATCH_9541        60.52      15.57
# 1         M1    Plastic Component  BATCH_7778        73.72      18.16
# 2         M2  High Strength Steel  BATCH_7076        72.02      29.36
# 3         M3      Aluminium Plate  BATCH_7400        66.57      29.10
# 4         M2  High Strength Steel  BATCH_2557        56.80      13.99
#
#    pressure  tool_wear  machine_speed  cooling_rate  cycle_time  ...  \
# 0    193.97      21.20        1055.59         14.78       16.22  ...
# 1    161.66      38.68        1286.48          9.93       15.43  ...
# 2    227.15      44.35        1203.44          9.70       15.31  ...
# 3    232.12      13.62        1004.65         12.12       12.40  ...
# 4    199.34      37.12        1168.91          6.50        8.47  ...
#
#   material_quality operator_skill_level stress_index  defect_type is_defect  \
# ...

# %%
df_anomaly.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 230568 entries, 0 to 249999
# Data columns (total 21 columns):
#  #   Column                Non-Null Count   Dtype
# ---  ------                --------------   -----
#  0   machine_id            230568 non-null  object
#  1   product_type          230568 non-null  object
#  2   batch_id              230568 non-null  object
#  3   temperature           230568 non-null  float64
#  4   vibration             230568 non-null  float64
#  5   pressure              230568 non-null  float64
#  6   tool_wear             230568 non-null  float64
#  7   machine_speed         230568 non-null  float64
#  8   cooling_rate          230568 non-null  float64
#  9   cycle_time            230568 non-null  float64
#  10  product_sensitivity   230568 non-null  object
#  11  material_quality      230568 non-null  object
#  12  operator_skill_level  230568 non-null  object
#  13  stress_index          230568 non-null  float64
# ...

# %%
df_corr2=df_anomaly.drop(columns=['machine_id','product_type','batch_id','product_sensitivity','material_quality','operator_skill_level','defect_type','quality_level'])

# %%
plt.figure(figsize=(20,10))
sns.heatmap(df_corr2.corr(),annot=True)
plt.show()

# %%
df_defect=df.copy()

# %%
df_defect.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 230568 entries, 0 to 249999
# Data columns (total 18 columns):
#  #   Column                Non-Null Count   Dtype
# ---  ------                --------------   -----
#  0   machine_id            230568 non-null  object
#  1   product_type          230568 non-null  object
#  2   batch_id              230568 non-null  object
#  3   temperature           230568 non-null  float64
#  4   vibration             230568 non-null  float64
#  5   pressure              230568 non-null  float64
#  6   tool_wear             230568 non-null  float64
#  7   machine_speed         230568 non-null  float64
#  8   cooling_rate          230568 non-null  float64
#  9   cycle_time            230568 non-null  float64
#  10  product_sensitivity   230568 non-null  object
#  11  material_quality      230568 non-null  object
#  12  operator_skill_level  230568 non-null  object
#  13  stress_index          230568 non-null  float64
# ...

# %%
categs=['product_type','product_sensitivity','material_quality','operator_skill_level']

# %%
numerics=['temperature','vibration','pressure','machine_speed','cooling_rate','cycle_time']

# %%
x_defect=df_defect[categs+numerics]

# %%
x_defect.head()
# Out:
#           product_type product_sensitivity material_quality  \
# 0      Aluminium Plate                High           Medium
# 1    Plastic Component                High           Medium
# 2  High Strength Steel              Medium             High
# 3      Aluminium Plate                High              Low
# 4  High Strength Steel                 Low             High
#
#   operator_skill_level  temperature  vibration  pressure  machine_speed  \
# 0               Expert        60.52      15.57    193.97        1055.59
# 1               Junior        73.72      18.16    161.66        1286.48
# 2         Intermediate        72.02      29.36    227.15        1203.44
# 3         Intermediate        66.57      29.10    232.12        1004.65
# 4         Intermediate        56.80      13.99    199.34        1168.91
#
#    cooling_rate  cycle_time
# 0         14.78       16.22
# 1          9.93       15.43
# 2          9.70       15.31
# 3         12.12       12.40
# ...

# %%
x_defect.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 230568 entries, 0 to 249999
# Data columns (total 10 columns):
#  #   Column                Non-Null Count   Dtype
# ---  ------                --------------   -----
#  0   product_type          230568 non-null  object
#  1   product_sensitivity   230568 non-null  object
#  2   material_quality      230568 non-null  object
#  3   operator_skill_level  230568 non-null  object
#  4   temperature           230568 non-null  float64
#  5   vibration             230568 non-null  float64
#  6   pressure              230568 non-null  float64
#  7   machine_speed         230568 non-null  float64
#  8   cooling_rate          230568 non-null  float64
#  9   cycle_time            230568 non-null  float64
# dtypes: float64(6), object(4)
# memory usage: 19.4+ MB

# %%
y_defect=df_defect['is_defect']

# %%
train_x_defect,test_x_defect,train_y_defect,test_y_defect=train_test_split(x_defect,y_defect,test_size=0.3,random_state=42)

# %%
train_x_defect.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 161397 entries, 205246 to 132269
# Data columns (total 10 columns):
#  #   Column                Non-Null Count   Dtype
# ---  ------                --------------   -----
#  0   product_type          161397 non-null  object
#  1   product_sensitivity   161397 non-null  object
#  2   material_quality      161397 non-null  object
#  3   operator_skill_level  161397 non-null  object
#  4   temperature           161397 non-null  float64
#  5   vibration             161397 non-null  float64
#  6   pressure              161397 non-null  float64
#  7   machine_speed         161397 non-null  float64
#  8   cooling_rate          161397 non-null  float64
#  9   cycle_time            161397 non-null  float64
# dtypes: float64(6), object(4)
# memory usage: 13.5+ MB

# %%
train_y_defect.head()
# Out:
# 205246    0
# 52963     0
# 160461    0
# 206152    1
# 103510    1
# Name: is_defect, dtype: int64

# %%
preprocess=ColumnTransformer([
    ('oht',OneHotEncoder(drop='first'),categs),
    ('std',StandardScaler(),numerics)
])

# %%
features=FeatureUnion([
    ('skt',SelectKBest(score_func=f_classif))
])

# %%
xg=XGBClassifier()
rf=RandomForestClassifier()

# %%
ensemble=VotingClassifier(
    estimators=[('xg',xg),
                ('rf',rf)],
    voting='soft'
)

# %%
defect_pipeline=Pipeline([
    ('preprocess',preprocess),
    ('features',features),
    ('ens',ensemble)
])

# %%
param_grid={
    "ens__xg__n_estimators":[50,150],
    "ens__xg__max_depth":[2,5],
    "ens__rf__n_estimators":[50,150],
    "ens__rf__max_depth":[2,7]
}

# %%
defect_grid=GridSearchCV(
    param_grid=param_grid,
    estimator=defect_pipeline,
    cv=7
)

# %%
defect_grid.fit(train_x_defect,train_y_defect)
# Out:
# GridSearchCV(cv=7,
#              estimator=Pipeline(steps=[('preprocess',
#                                         ColumnTransformer(transformers=[('oht',
#                                                                          OneHotEncoder(drop='first'),
#                                                                          ['product_type',
#                                                                           'product_sensitivity',
#                                                                           'material_quality',
#                                                                           'operator_skill_level']),
#                                                                         ('std',
#                                                                          StandardScaler(),
#                                                                          ['temperature',
# ...

# %%
detect_preds=defect_grid.predict(test_x_defect)

# %%
defect_proba=defect_grid.predict_proba(test_x_defect)[:,1]

# %%
## printing the classification report and then threshold tuning

# %%
print(classification_report(test_y_defect,detect_preds))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.95      1.00      0.97     55290
#            1       0.99      0.79      0.88     13881
#
#     accuracy                           0.96     69171
#    macro avg       0.97      0.89      0.93     69171
# weighted avg       0.96      0.96      0.95     69171

# %%
for k in [0.5,0.4,0.3,0.2]:
    preds=(defect_proba>=k).astype(int)
    print("\nThreshold",k)
    print(classification_report(test_y_defect,preds))
# Out:
# Threshold 0.5
#               precision    recall  f1-score   support
#
#            0       0.95      1.00      0.97     55290
#            1       0.99      0.79      0.88     13881
#
#     accuracy                           0.96     69171
#    macro avg       0.97      0.89      0.93     69171
# weighted avg       0.96      0.96      0.95     69171
#
#
# Threshold 0.4
#               precision    recall  f1-score   support
#
#            0       0.95      1.00      0.97     55290
#            1       0.99      0.79      0.88     13881
#
#     accuracy                           0.96     69171
#    macro avg       0.97      0.89      0.93     69171
# weighted avg       0.96      0.96      0.95     69171
#
#
# Threshold 0.3
#               precision    recall  f1-score   support
#
#            0       0.95      1.00      0.97     55290
#            1       0.98      0.79      0.88     13881
#
#     accuracy                           0.96     69171
# ...

# %%
threshold=0.3

# %%
joblib.dump(threshold,'threshold.pkl')
# Out:
# ['threshold.pkl']

# %%
joblib.dump(defect_grid,"defect_probability_model.pkl")
# Out:
# ['defect_probability_model.pkl']

# %% [markdown]
# ## Moving On to the third Model where we predict the type of defect

# %%
categs=['product_type','product_sensitivity','material_quality','operator_skill_level']

# %%
numerics=['temperature','vibration','pressure','machine_speed','cooling_rate','cycle_time']

# %%
df_type=df.copy()

# %%
df_type.head()
# Out:
#   machine_id         product_type    batch_id  temperature  vibration  \
# 0         M2      Aluminium Plate  BATCH_9541        60.52      15.57
# 1         M1    Plastic Component  BATCH_7778        73.72      18.16
# 2         M2  High Strength Steel  BATCH_7076        72.02      29.36
# 3         M3      Aluminium Plate  BATCH_7400        66.57      29.10
# 4         M2  High Strength Steel  BATCH_2557        56.80      13.99
#
#    pressure  tool_wear  machine_speed  cooling_rate  cycle_time  \
# 0    193.97      21.20        1055.59         14.78       16.22
# 1    161.66      38.68        1286.48          9.93       15.43
# 2    227.15      44.35        1203.44          9.70       15.31
# 3    232.12      13.62        1004.65         12.12       12.40
# 4    199.34      37.12        1168.91          6.50        8.47
#
#   product_sensitivity material_quality operator_skill_level  stress_index  \
# 0                High           Medium               Expert          9.42
# ...

# %%
y_type=df_type['defect_type']

# %%
x_type=df_type[categs+numerics]

# %%
x_type.head()
# Out:
#           product_type product_sensitivity material_quality  \
# 0      Aluminium Plate                High           Medium
# 1    Plastic Component                High           Medium
# 2  High Strength Steel              Medium             High
# 3      Aluminium Plate                High              Low
# 4  High Strength Steel                 Low             High
#
#   operator_skill_level  temperature  vibration  pressure  machine_speed  \
# 0               Expert        60.52      15.57    193.97        1055.59
# 1               Junior        73.72      18.16    161.66        1286.48
# 2         Intermediate        72.02      29.36    227.15        1203.44
# 3         Intermediate        66.57      29.10    232.12        1004.65
# 4         Intermediate        56.80      13.99    199.34        1168.91
#
#    cooling_rate  cycle_time
# 0         14.78       16.22
# 1          9.93       15.43
# 2          9.70       15.31
# 3         12.12       12.40
# ...

# %%
train_x_type,test_x_type,train_y_type,test_y_type=train_test_split(x_type,y_type,test_size=0.3,random_state=42)

# %%
train_x_type.head()
# Out:
#                product_type product_sensitivity material_quality  \
# 205246  High Strength Steel              Medium             High
# 52963     Plastic Component                 Low              Low
# 160461  High Strength Steel                High              Low
# 206152    Plastic Component                High           Medium
# 103510  High Strength Steel                 Low              Low
#
#        operator_skill_level  temperature  vibration  pressure  machine_speed  \
# 205246               Expert        59.43      10.00    180.36        1087.02
# 52963                Expert        67.92      14.80    216.17        1107.71
# 160461               Expert        67.32      21.07    177.86        1142.90
# 206152         Intermediate       100.96      12.38    168.06        1080.49
# 103510         Intermediate        61.67      29.09    171.60        1163.88
#
#         cooling_rate  cycle_time
# 205246         10.04       11.89
# 52963          11.29       13.88
# ...

# %%
train_y_type.head()
# Out:
# 205246      No defect
# 52963       No defect
# 160461      No defect
# 206152        Warping
# 103510    Deformation
# Name: defect_type, dtype: object

# %%
preprocess=ColumnTransformer([
    ('oht',OneHotEncoder(drop='first'),categs),
    ('std',StandardScaler(),numerics)
])

# %%
features=FeatureUnion([
    ('skt',SelectKBest(score_func=f_classif))
])

# %%
rf=RandomForestClassifier(class_weight="balanced")

# %%
type_pipeline=Pipeline([
    ('preprocess',preprocess),
    ('features',features),
    ('rf',rf)
])

# %%
param_grid={

    "rf__n_estimators":[50,150],
    "rf__max_depth":[2,7],
    
}

# %%
type_grid=GridSearchCV(
    param_grid=param_grid,
    estimator=type_pipeline,
    cv=7,
    verbose=2
)

# %%
type_grid.fit(train_x_type,train_y_type)
# Out:
# Fitting 7 folds for each of 4 candidates, totalling 28 fits
# [CV] END ...............rf__max_depth=2, rf__n_estimators=50; total time=   7.8s
# [CV] END ...............rf__max_depth=2, rf__n_estimators=50; total time=   7.5s
# [CV] END ...............rf__max_depth=2, rf__n_estimators=50; total time=   7.6s
# [CV] END ...............rf__max_depth=2, rf__n_estimators=50; total time=   7.8s
# [CV] END ...............rf__max_depth=2, rf__n_estimators=50; total time=   7.7s
# [CV] END ...............rf__max_depth=2, rf__n_estimators=50; total time=   7.2s
# [CV] END ...............rf__max_depth=2, rf__n_estimators=50; total time=   7.4s
# [CV] END ..............rf__max_depth=2, rf__n_estimators=150; total time=  18.2s
# [CV] END ..............rf__max_depth=2, rf__n_estimators=150; total time=  18.8s
# [CV] END ..............rf__max_depth=2, rf__n_estimators=150; total time=  19.7s
# [CV] END ..............rf__max_depth=2, rf__n_estimators=150; total time=  16.9s
# ...

# %%
type_preds=type_grid.predict(test_x_type)

# %%
type_preds
# Out:
# array(['No defect', 'No defect', 'Porosity', ..., 'Porosity', 'Porosity',
#        'Deformation'], dtype=object)

# %%
x=test_x_type.copy()

# %%
x['type_prediction']=type_preds

# %%
x.head()
# Out:
#                product_type product_sensitivity material_quality  \
# 143869  High Strength Steel                 Low           Medium
# 247660  High Strength Steel                 Low             High
# 16482       Aluminium Plate              Medium              Low
# 171966      Aluminium Plate                High           Medium
# 151958  High Strength Steel                High             High
#
#        operator_skill_level  temperature  vibration  pressure  machine_speed  \
# 143869         Intermediate        57.99      28.05    158.54        1099.98
# 247660         Intermediate        55.51      26.98    150.06        1233.18
# 16482                Expert        53.14      16.22    249.65        1288.14
# 171966               Expert        70.72      55.25    203.04        1286.68
# 151958         Intermediate        54.97      27.58    208.80         993.25
#
#         cooling_rate  cycle_time type_prediction
# 143869         10.51       10.29       No defect
# ...

# %%
print(classification_report(test_y_type,type_preds))
# Out:
#                 precision    recall  f1-score   support
#
#    Deformation       1.00      1.00      1.00      2844
#   Misalignment       0.83      0.99      0.90      2736
#      No defect       1.00      0.65      0.79     55290
#       Porosity       0.13      0.96      0.23      2762
# Surface_Defect       0.70      0.96      0.81      2759
#        Warping       1.00      1.00      1.00      2780
#
#       accuracy                           0.72     69171
#      macro avg       0.78      0.93      0.79     69171
#   weighted avg       0.95      0.72      0.79     69171

# %%
confusion_matrix(test_y_type,type_preds)
# Out:
# array([[ 2844,     0,     0,     0,     0,     0],
#        [    0,  2719,     2,     3,    12,     0],
#        [    0,   484, 36001, 17744,  1061,     0],
#        [    0,    25,    32,  2653,    52,     0],
#        [    0,    48,    40,    21,  2650,     0],
#        [    0,     0,     0,     0,     0,  2780]])

# %%
sns.heatmap(confusion_matrix(test_y_type,type_preds),annot=True,fmt='d')
plt.xlabel('Predicted')
plt.ylabel('Actual')
# Out:
# Text(50.722222222222214, 0.5, 'Actual')

# %%
joblib.dump(type_grid,'defect_type_model.pkl')
# Out:
# ['defect_type_model.pkl']

# %% [markdown]
# ## MOVING ON TO THE FINAL MODEL OF PREDICTING PRODUCT QUALITY

# %%
from sklearn import linear_model

# %%
df_quality=df.copy()

# %%
df_quality.describe()
# Out:
#          temperature      vibration       pressure      tool_wear  \
# count  230568.000000  230568.000000  230568.000000  230568.000000
# mean       64.934424      21.243970     197.720187      32.023476
# std        40.240650      16.368736     119.461622      26.067968
# min      -328.680000    -200.250000    -748.830000    -290.140000
# 25%        56.790000      14.960000     173.980000      20.030000
# 50%        64.190000      20.380000     199.870000      30.850000
# 75%        71.510000      25.822500     226.080000      41.670000
# max       525.440000     329.490000    1245.140000     466.590000
#
#        machine_speed   cooling_rate     cycle_time   stress_index  \
# count  230568.000000  230568.000000  230568.000000  230568.000000
# mean     1099.950575       9.697263      13.488769      14.324656
# std       115.491516       3.190880       3.735295       7.884156
# min       900.000000       1.000000       8.000000       5.010000
# ...

# %%
df_quality.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 230568 entries, 0 to 249999
# Data columns (total 18 columns):
#  #   Column                Non-Null Count   Dtype
# ---  ------                --------------   -----
#  0   machine_id            230568 non-null  object
#  1   product_type          230568 non-null  object
#  2   batch_id              230568 non-null  object
#  3   temperature           230568 non-null  float64
#  4   vibration             230568 non-null  float64
#  5   pressure              230568 non-null  float64
#  6   tool_wear             230568 non-null  float64
#  7   machine_speed         230568 non-null  float64
#  8   cooling_rate          230568 non-null  float64
#  9   cycle_time            230568 non-null  float64
#  10  product_sensitivity   230568 non-null  object
#  11  material_quality      230568 non-null  object
#  12  operator_skill_level  230568 non-null  object
#  13  stress_index          230568 non-null  float64
# ...

# %%
df_quality.head()
# Out:
#   machine_id         product_type    batch_id  temperature  vibration  \
# 0         M2      Aluminium Plate  BATCH_9541        60.52      15.57
# 1         M1    Plastic Component  BATCH_7778        73.72      18.16
# 2         M2  High Strength Steel  BATCH_7076        72.02      29.36
# 3         M3      Aluminium Plate  BATCH_7400        66.57      29.10
# 4         M2  High Strength Steel  BATCH_2557        56.80      13.99
#
#    pressure  tool_wear  machine_speed  cooling_rate  cycle_time  \
# 0    193.97      21.20        1055.59         14.78       16.22
# 1    161.66      38.68        1286.48          9.93       15.43
# 2    227.15      44.35        1203.44          9.70       15.31
# 3    232.12      13.62        1004.65         12.12       12.40
# 4    199.34      37.12        1168.91          6.50        8.47
#
#   product_sensitivity material_quality operator_skill_level  stress_index  \
# 0                High           Medium               Expert          9.42
# ...

# %%
categs=['product_type','product_sensitivity','material_quality','operator_skill_level']

# %%
numerics=['temperature','vibration','pressure','machine_speed','cooling_rate','cycle_time']

# %%
x_quality=df_quality[categs+numerics]

# %%
df_quality.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 230568 entries, 0 to 249999
# Data columns (total 18 columns):
#  #   Column                Non-Null Count   Dtype
# ---  ------                --------------   -----
#  0   machine_id            230568 non-null  object
#  1   product_type          230568 non-null  object
#  2   batch_id              230568 non-null  object
#  3   temperature           230568 non-null  float64
#  4   vibration             230568 non-null  float64
#  5   pressure              230568 non-null  float64
#  6   tool_wear             230568 non-null  float64
#  7   machine_speed         230568 non-null  float64
#  8   cooling_rate          230568 non-null  float64
#  9   cycle_time            230568 non-null  float64
#  10  product_sensitivity   230568 non-null  object
#  11  material_quality      230568 non-null  object
#  12  operator_skill_level  230568 non-null  object
#  13  stress_index          230568 non-null  float64
# ...

# %%
y_quality=df_quality['quality_score']

# %%
x_quality.head()
# Out:
#           product_type product_sensitivity material_quality  \
# 0      Aluminium Plate                High           Medium
# 1    Plastic Component                High           Medium
# 2  High Strength Steel              Medium             High
# 3      Aluminium Plate                High              Low
# 4  High Strength Steel                 Low             High
#
#   operator_skill_level  temperature  vibration  pressure  machine_speed  \
# 0               Expert        60.52      15.57    193.97        1055.59
# 1               Junior        73.72      18.16    161.66        1286.48
# 2         Intermediate        72.02      29.36    227.15        1203.44
# 3         Intermediate        66.57      29.10    232.12        1004.65
# 4         Intermediate        56.80      13.99    199.34        1168.91
#
#    cooling_rate  cycle_time
# 0         14.78       16.22
# 1          9.93       15.43
# 2          9.70       15.31
# 3         12.12       12.40
# ...

# %%
y_quality.head()
# Out:
# 0    73.84
# 1    66.95
# 2    70.35
# 3    88.58
# 4    74.63
# Name: quality_score, dtype: float64

# %%
train_x_quality,test_x_quality,train_y_quality,test_y_quality=train_test_split(x_quality,y_quality,test_size=0.3,random_state=42)

# %%
train_x_quality.head()
# Out:
#                product_type product_sensitivity material_quality  \
# 205246  High Strength Steel              Medium             High
# 52963     Plastic Component                 Low              Low
# 160461  High Strength Steel                High              Low
# 206152    Plastic Component                High           Medium
# 103510  High Strength Steel                 Low              Low
#
#        operator_skill_level  temperature  vibration  pressure  machine_speed  \
# 205246               Expert        59.43      10.00    180.36        1087.02
# 52963                Expert        67.92      14.80    216.17        1107.71
# 160461               Expert        67.32      21.07    177.86        1142.90
# 206152         Intermediate       100.96      12.38    168.06        1080.49
# 103510         Intermediate        61.67      29.09    171.60        1163.88
#
#         cooling_rate  cycle_time
# 205246         10.04       11.89
# 52963          11.29       13.88
# ...

# %%
test_y_quality.head()
# Out:
# 143869    72.22
# 247660    75.58
# 16482     85.72
# 171966    33.44
# 151958    82.56
# Name: quality_score, dtype: float64

# %%
preprocess=ColumnTransformer([
    ('oht',OneHotEncoder(drop='first'),categs),
    ('std',StandardScaler(),numerics)
])

# %%
features=FeatureUnion([
    ('skt',SelectKBest(score_func=f_regression,k=10))
])

# %%
rf=RandomForestRegressor()

# %%
quality_pipeline=Pipeline([
    ('preprocess',preprocess),
    ('features',features),
    ('rf',rf)
])

# %%
param={
    "rf__n_estimators":[50],
    "rf__max_depth":[None],
}

# %%
quality_grid=GridSearchCV(
    param_grid=param,
    estimator=quality_pipeline,
    cv=3,
    n_jobs=1,
    verbose=2
)

# %%
quality_grid.fit(train_x_quality,train_y_quality)
# Out:
# Fitting 3 folds for each of 1 candidates, totalling 3 fits
# [CV] END ............rf__max_depth=None, rf__n_estimators=50; total time= 1.8min
# [CV] END ............rf__max_depth=None, rf__n_estimators=50; total time= 2.0min
# [CV] END ............rf__max_depth=None, rf__n_estimators=50; total time= 2.2min
# GridSearchCV(cv=3,
#              estimator=Pipeline(steps=[('preprocess',
#                                         ColumnTransformer(transformers=[('oht',
#                                                                          OneHotEncoder(drop='first'),
#                                                                          ['product_type',
#                                                                           'product_sensitivity',
#                                                                           'material_quality',
#                                                                           'operator_skill_level']),
# ...

# %%
quality_preds=quality_grid.predict(test_x_quality)

# %%
quality_preds=quality_preds.round(2)

# %%
test=test_x_quality.copy()

# %%
test['quality_preds']=quality_preds

# %%
print((test['quality_preds']>100).sum())
# Out:
# 0

# %%
joblib.dump(quality_grid,"quality_prediction_model3.pkl")
# Out:
# ['quality_prediction_model3.pkl']

# %% [markdown]
# # MOVING ON TO DESIGN OUR MCDF

# %%
product_quality=joblib.load(r"C:\Users\user\Desktop\Product_Management_system\models\quality_prediction_model3.pkl")
defect_type=joblib.load(r"C:\Users\user\Desktop\Product_Management_system\models\defect_type_model.pkl")
defect_probability=joblib.load(r"C:\Users\user\Desktop\Product_Management_system\models\defect_probability_model.pkl")
anomaly=joblib.load(r"C:\Users\user\Desktop\Product_Management_system\models\anomaly_model.pkl")

# %% [markdown]
# #### creating a new sample dataframe

# %%
x_new=pd.DataFrame({
    "product_type":['Aluminium Plate','High Strength Steel','Plastic Component'],
    "temperature":[90.5,80.4,70.7],
    "vibration":[13.5,5.9,10.6],
    "pressure":[94,4.8,130.7],
    "tool_wear":[10.9,20.6,3.9],
    "machine_speed":[1000,1200,1200],
    "cooling_rate":[14.78,55.7,10.6],
    "cycle_time":[3.7,10.3,3.1],
    "product_sensitivity":['High','Medium','Low'],
    "material_quality":['High','Medium','High'],
    "operator_skill_level":['Expert','Intermediate','Expert'],
    "stress_index":[4.5,50.8,15.4],
    "quality_level":['High','Medium','High']  
},index=['machine_1','machine_2','machine_3'])

# %%
anomaly_flag=anomaly.predict(x_new)
defect_proba=defect_probability.predict_proba(x_new)[:,1]
defect_type=defect_type.predict(x_new)
quality=product_quality.predict(x_new)

# %%
anomaly_binary=np.where(anomaly_flag==-1,1,0)

# %%
DEFCT_WEIGHTS={
    "Deformation":0.9,
    "Misalignment":0.6,
    "No defect":0.1,
    "Porosity":0.5,
    "Surface_Defect":0.7,
    "Warping":0.8
}

# %%
defect_score=np.array([DEFCT_WEIGHTS[d] for d in defect_type])

# %%
print(defect_score)
print(anomaly_binary)
# Out:
# [0.7 0.7 0.1]
# [1 1 0]

# %%
criteria=np.column_stack([anomaly_binary,defect_proba,defect_score,quality])

# %%
print(criteria)
# Out:
# [[1.00000000e+00 9.46388685e-01 7.00000000e-01 3.04312000e+01]
#  [1.00000000e+00 9.43431179e-01 7.00000000e-01 2.93094000e+01]
#  [0.00000000e+00 1.51843708e-02 1.00000000e-01 7.61450000e+01]]

# %%
from sklearn.preprocessing import MinMaxScaler

# %%
scaler=MinMaxScaler()

# %%
criteria_norm=scaler.fit_transform(criteria)

# %%
print(criteria_norm)
# Out:
# [[1.         1.         1.         0.02395187]
#  [1.         0.996824   1.         0.        ]
#  [0.         0.         0.         1.        ]]

# %%
weights=np.array([0.35,0.3,0.20,0.15])

# %%
final_score=np.dot(criteria_norm,weights)

# %%
def product_decision(row):
    quality=row['quality']
    probability=row['defect_proba']
    if probability>0.6 or quality<60:
        return "PRODUCT NOT ACCEPTABLE"
    elif probability>0.4 or quality<70:
        return "DO SECOND INSPECTION"
    else:
        return "ACCEPT PRODUCT"

# %%
def machine_decision(row):
    score=row['final_score']
    anomaly=row['anomaly_binary'] == "ANOMALY DETECTED"
    if anomaly==1 and score>0.7:
        return "STOP MACHINE IMMEDIATELY"
    elif anomaly==1 or score>0.4:
        return "MONITOR MACHINE"
    else:
        if score>=0.7:
            return "STOP MACHINE IMMEDIATELY"
        elif score>=0.4:
            return "MONITOR MACHINE"
        else:
            return "MACHINE STABLE"

# %%
def final_decision(row):
    product=product_decision(row)
    machine=machine_decision(row)
    if product=="PRODUCT NOT ACCEPTABLE" and machine == "STOP MACHINE IMMEDIATELY":
        return "STOP OPERATIONS IMMEDIATELY"
    elif product=="DO SECOND INSPECTION" or machine == "MONITOR MACHINE":
        return "INSPECT PROCESS"
    else:
        return "NORMAL OPERATIONS"

# %%
machines=pd.DataFrame({
    "machine_id":x_new.index,
    "anomaly_binary":anomaly_binary,
    "defect_proba":defect_proba,
    "defect_type":defect_type,
    "quality":quality,
    "final_score":final_score
})

# %%
machines["anomaly_binary"]=machines["anomaly_binary"].apply(
    lambda x: "ANOMALY DETECTED" if x==1 else "OKAY"
)

# %%
machines['product_decision']=machines.apply(product_decision,axis=1)

# %%
machines['machine_decision']=machines.apply(machine_decision,axis=1)

# %%
machines['final_decision']=machines.apply(final_decision,axis=1)

# %%
machines
# Out:
#   machine_id    anomaly_binary  defect_proba     defect_type  quality  \
# 0  machine_1  ANOMALY DETECTED      0.946389  Surface_Defect  30.4312
# 1  machine_2  ANOMALY DETECTED      0.943431  Surface_Defect  29.3094
# 2  machine_3              OKAY      0.015184       No defect  76.1450
#
#    final_score        product_decision          machine_decision  \
# 0     0.853593  PRODUCT NOT ACCEPTABLE  STOP MACHINE IMMEDIATELY
# 1     0.849047  PRODUCT NOT ACCEPTABLE  STOP MACHINE IMMEDIATELY
# 2     0.150000          ACCEPT PRODUCT            MACHINE STABLE
#
#                 final_decision
# 0  STOP OPERATIONS IMMEDIATELY
# 1  STOP OPERATIONS IMMEDIATELY
# 2            NORMAL OPERATIONS

# %%
joblib.dump(scaler,"models/scaler.pkl")
# Out:
# ['models/scaler.pkl']

# %%
import os
print(os.getcwd())
# Out:
# C:\Users\user\Desktop\Product_Management_system

# %%
import mlflow
import mlflow.sklearn

# %%
mlflow.set_experiment("Product Management System")
mlflow.set_tracking_uri("http://127.0.0.1:5000")
# Out:
# C:\Users\user\AppData\Local\Programs\Python\Python312\Lib\site-packages\mlflow\tracking\_tracking_service\utils.py:184: FutureWarning: The filesystem tracking backend (e.g., './mlruns') is deprecated as of February 2026. Consider transitioning to a database backend (e.g., 'sqlite:///mlflow.db') to take advantage of the latest MLflow features. See https://mlflow.org/docs/latest/self-hosting/migrate-from-file-store for migration guidance.
#   return FileStore(store_uri, store_uri)

# %%
product_quality=joblib.load(r"C:\Users\user\Desktop\Product_Management_system\models\quality_prediction_model3.pkl")
defect_type=joblib.load(r"C:\Users\user\Desktop\Product_Management_system\models\defect_type_model.pkl")
defect_probability=joblib.load(r"C:\Users\user\Desktop\Product_Management_system\models\defect_probability_model.pkl")
anomaly=joblib.load(r"C:\Users\user\Desktop\Product_Management_system\models\anomaly_model.pkl")
threshod=joblib.load(r"C:\Users\user\Desktop\Product_Management_system\models\threshold.pkl")
# Out:
# ---------------------------------------------------------------------------
# MemoryError                               Traceback (most recent call last)
# Cell In[259], line 1
# ----> 1 product_quality=joblib.load(r"C:\Users\user\Desktop\Product_Management_system\models\quality_prediction_model3.pkl")
#       2 defect_type=joblib.load(r"C:\Users\user\Desktop\Product_Management_system\models\defect_type_model.pkl")
#       3 defect_probability=joblib.load(r"C:\Users\user\Desktop\Product_Management_system\models\defect_probability_model.pkl")
#
# File ~\AppData\Local\Programs\Python\Python312\Lib\site-packages\joblib\numpy_pickle.py:749, in load(filename, mmap_mode, ensure_native_byte_order)
#     744                 return load_compatibility(fobj)
#     746             # A memory-mapped array has to be mapped with the endianness
#     747             # it has been written with. Other arrays are coerced to the
#     748             # native endianness of the host system.
# ...

# %%
with mlflow.start_run(run_name="defect_type"):
    mlflow.log_param("model_type","Classification")
    mlflow.log_metric("f1_score",f1_score(test_y_type,type_preds,average='weighted'))
    mlflow.log_metric("precision_score",precision_score(test_y_type,type_preds,average='weighted'))
    mlflow.log_metric("recall_score",recall_score(test_y_type,type_preds,average='weighted'))
    mlflow.sklearn.log_model(defect_type,"defect_type")
with mlflow.start_run(run_name="defect_probability"):
    mlflow.log_param("model_type","Classification")
    mlflow.log_param("threshold",threshold)
    mlflow.log_metric("f1_score",f1_score(test_y_defect,detect_preds))
    mlflow.log_metric("precision_score",precision_score(test_y_defect,detect_preds))
    mlflow.log_metric("recall_score",recall_score(test_y_defect,detect_preds))
    mlflow.sklearn.log_model(defect_probability,"defect_probability")

with mlflow.start_run(run_name="product_quality"):
    mlflow.log_param("model_type","RandomForestRegression")
    mlflow.log_metric("r2_score",r2_score(test_y_quality,quality_preds))
    mlflow.log_metric("MAE",mean_absolute_error(test_y_quality,quality_preds))
    mlflow.log_metric("MSE",mean_squared_error(test_y_quality,quality_preds))
    mlflow.sklearn.log_model(product_quality,"product_quality")
mlflow.end_run()
